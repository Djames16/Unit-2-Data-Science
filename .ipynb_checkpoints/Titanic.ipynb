# %%
import pandas as pd

df = pd.read_csv("titanic.csv")

# I imported pandas as pd so that I can access pandas and assign it the easy to reach name of pd. Then set it equal to df so that I would be able to access the Titanic file.
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\Daeon\Unit-2-Data-Science-1\.ipynb_checkpoints\Titanic.ipynb Cell 1 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/Daeon/Unit-2-Data-Science-1/.ipynb_checkpoints/Titanic.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> import pandas as pd
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Daeon/Unit-2-Data-Science-1/.ipynb_checkpoints/Titanic.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> df = pd.read_csv("titanic.csv")
#       <a href='vscode-notebook-cell:/c%3A/Users/Daeon/Unit-2-Data-Science-1/.ipynb_checkpoints/Titanic.ipynb#W0sZmlsZQ%3D%3D?line=4'>5</a> # I imported pandas as pd so that I can access pandas and assign it the easy to reach name of pd. Then set it equal to df so that I would be able to access the Titanic file.
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'titanic.csv'

# %%
import matplotlib.pyplot as plt
y= df.groupby('Sex')['Survived'].mean()
x = ['Female', 'Male']
plt.xlabel("Gender")
plt.ylabel("Percentage")
cmap = plt.get_cmap ( "cubehelix")
plt. rcParams[ 'hatch.color'] = cmap(0.6)
plt. rcParams['hatch.linewidth']=8
plt.bar (x, y, color=cmap (0.1), hatch="/")
plt.title("Percentage by sex that survived")
# I imported matplotlib.pyplot as plt so that I would be able to access the ability to plot data and put it as plt so that it is easy to reach. I then set y to group by sex and survived so that the data that is looked at consists of that data. I then set the x axis to the data that I want to seperate. Then labels so that the data is specified then added some colors to it.
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\Daeon\Unit-2-Data-Science\Titanic.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Daeon/Unit-2-Data-Science/Titanic.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> import matplotlib.pyplot as plt
#       <a href='vscode-notebook-cell:/c%3A/Users/Daeon/Unit-2-Data-Science/Titanic.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> y= df.groupby('Sex')['Survived'].mean()
#       <a href='vscode-notebook-cell:/c%3A/Users/Daeon/Unit-2-Data-Science/Titanic.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> x = ['Female', 'Male']
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
y= df.groupby('Sex')['Age'].mean()
x= ['Female', 'Male']
plt.xlabel("Gender")
plt.ylabel("Age")
cmap = plt.get_cmap ( "twilight")
plt. rcParams[ 'hatch.color'] = cmap(0.5)
plt. rcParams['hatch.linewidth'] =8
plt.bar (x, y, color=cmap (0.4), hatch="/" )
plt.title("Age by sex")
#I  set y to group by sex and age so that the data that is looked at consists of that data. I then set the x axis to the data that I want to seperate. Then labels so that the data is specified then added some colors to it.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Daeon\Unit-2-Data-Science\Titanic.ipynb Cell 3 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/Daeon/Unit-2-Data-Science/Titanic.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> y= df.groupby('Sex')['Age'].mean()
#       <a href='vscode-notebook-cell:/c%3A/Users/Daeon/Unit-2-Data-Science/Titanic.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> x= ['Female', 'Male']
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Daeon/Unit-2-Data-Science/Titanic.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> plt.xlabel("Gender")
#       <a href='vscode-notebook-cell:/c%3A/Users/Daeon/Unit-2-Data-Science/Titanic.ipynb#W2sZmlsZQ%3D%3D?line=3'>4</a> plt.ylabel("Age")
#       <a href='vscode-notebook-cell:/c%3A/Users/Daeon/Unit-2-Data-Science/Titanic.ipynb#W2sZmlsZQ%3D%3D?line=4'>5</a> cmap = plt.get_cmap ( "twilight")
#
# NameError: name 'plt' is not defined

# %%
y= df.groupby('Pclass')['Survived'].mean()
x = ['1', '2','3']
plt.xlabel("Cabin")
plt.ylabel("Survived")
cmap = plt.get_cmap ( "rainbow")
plt. rcParams[ 'hatch.color'] = cmap(0.2)
plt. rcParams['hatch.linewidth'] =8
plt.bar (x, y, color=cmap (0.6), hatch="/" )
plt.title("Survived by cabin")
# I set y to group by Pclass and survived so that the data that is looked at consists of that data. I then set the x axis to the data that I want to seperate. Then labels so that the data is specified then added some colors to it.
# Out:
# Text(0.5, 1.0, 'Survived by cabin')
