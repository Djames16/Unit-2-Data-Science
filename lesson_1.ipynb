# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# Hello pretty world

# %%
import matplotlib.pyplot as plt
y=[1,2,3,4]
x=[22,87,0,18]
plt.plot(x,y)
plt.ylabel("Memes")
plt.xlabel("Trolls")
plt.title("Graph of the world")
# Out:
# Text(0.5, 1.0, 'Graph of the world')

# %%
height=[1,2,3,4]
x=[10,15,20,21]
plt.bar(x,height)
plt.xlabel("Trolls")
plt.ylabel("Memes")
plt.title("Graph of the world")
# Out:
# Text(0.5, 1.0, 'Graph of the world')

# %%
Z=[10,15,20,21]
plt.pie(x)
plt.xlabel("Trolls")
plt.ylabel("Memes")
plt.title("Graph of the world")
# Out:
# Text(0.5, 1.0, 'Graph of the world')
